# %%
print("hello numpy")
# Out:
# hello numpy

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "Salary": [50000, 60000, 70000]
}

df = pd.DataFrame(data)
print (df)
# Out:
#    Name  Salary
# 0   Ali   50000
# 1  Sara   60000
# 2  John   70000

# %%
df['Bonus']= df['Salary']*2
print(df)
# Out:
#    Name  Salary   Bonus
# 0   Ali   50000  100000
# 1  Sara   60000  120000
# 2  John   70000  140000

# %%
import pandas as pd

data = {
    "Hours_Study": [2, 4, 6, 8, None],
    "Attendance": [60, 70, 80, 90, 85],
    "Pass": ["No", "No", "Yes", "Yes", "Yes"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Hours_Study  Attendance Pass
# 0          2.0          60   No
# 1          4.0          70   No
# 2          6.0          80  Yes
# 3          8.0          90  Yes
# 4          NaN          85  Yes

# %%
df.isnull()
# Out:
#    Hours_Study  Attendance   Pass
# 0        False       False  False
# 1        False       False  False
# 2        False       False  False
# 3        False       False  False
# 4         True       False  False

# %%
df.isnull().sum()
# Out:
# Hours_Study    1
# Attendance     0
# Pass           0
# dtype: int64

# %%
df.dropna()
# Out:
#    Hours_Study  Attendance Pass
# 0          2.0          60   No
# 1          4.0          70   No
# 2          6.0          80  Yes
# 3          8.0          90  Yes

# %%
df["Hours_Study"].fillna(df["Hours_Study"].mean())
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    8.0
# 4    5.0
# Name: Hours_Study, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Hours_Study  4 non-null      float64
#  1   Attendance   5 non-null      int64
#  2   Pass         5 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes

# %%
df.describe()
# Out:
#        Hours_Study  Attendance
# count     4.000000    5.000000
# mean      5.000000   77.000000
# std       2.581989   12.041595
# min       2.000000   60.000000
# 25%       3.500000   70.000000
# 50%       5.000000   80.000000
# 75%       6.500000   85.000000
# max       8.000000   90.000000

# %%
df.sort_values("Attendance",ascending= False)
# Out:
#    Hours_Study  Attendance Pass
# 3          8.0          90  Yes
# 4          NaN          85  Yes
# 2          6.0          80  Yes
# 1          4.0          70   No
# 0          2.0          60   No

# %%
df["Attendance"].value_counts()
# Out:
# Attendance
# 60    1
# 70    1
# 80    1
# 90    1
# 85    1
# Name: count, dtype: int64

# %%
df["Attendance"].unique()
# Out:
# array([60, 70, 80, 90, 85])

# %%
df["Attendance"].nunique()
# Out:
# 5

# %%
import pandas as pd

data = {
    "Customer": ["Rahim", "Karim", "Sakib"],
    "City": ["Dhaka", "Sylhet", "Chittagong"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Customer        City
# 0    Rahim       Dhaka
# 1    Karim      Sylhet
# 2    Sakib  Chittagong

# %%
df2 = pd.get_dummies(df["City"], dtype=int)

# %%
print(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(df2)
#
# NameError: name 'df2' is not defined

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "City": ["Dhaka", "Chittagong", "Dhaka"]
}

df = pd.DataFrame(data)

df2 = pd.get_dummies(df["City"], dtype=int)

print(df2)
# Out:
#    Chittagong  Dhaka
# 0           0      1
# 1           1      0
# 2           0      1

# %%
import pandas as pd

data = {
    "Food": ["Burger", "Pizza", "Burger", "Pasta"]
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#      Food
# 0  Burger
# 1   Pizza
# 2  Burger
# 3   Pasta

# %%
encoded= pd.get_dummies(df["Food"],dtype=int)

# %%
print(encoded)
# Out:
#    Burger  Pasta  Pizza
# 0       1      0      0
# 1       0      0      1
# 2       1      0      0
# 3       0      1      0

# %%
print(encoded.shape[1])
# Out:
# 3

# %%
print(encoded.iloc[1])
# Out:
# Burger    0
# Pasta     0
# Pizza     1
# Name: 1, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C", "D", "E"],
    "Age": [20, 22, None, 25, 30],
    "Salary": [20000, 25000, 30000, None, 50000],
    "Department": ["IT", "HR", "IT", "HR", "IT"]
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   Name   Age   Salary Department
# 0    A  20.0  20000.0         IT
# 1    B  22.0  25000.0         HR
# 2    C   NaN  30000.0         IT
# 3    D  25.0      NaN         HR
# 4    E  30.0  50000.0         IT

# %%
df.iloc[0:3]
# Out:
#   Name   Age   Salary Department
# 0    A  20.0  20000.0         IT
# 1    B  22.0  25000.0         HR
# 2    C   NaN  30000.0         IT

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'Department'], dtype='object')

# %%
df.isnull()
# Out:
#     Name    Age  Salary  Department
# 0  False  False   False       False
# 1  False  False   False       False
# 2  False   True   False       False
# 3  False  False    True       False
# 4  False  False   False       False

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           1
# Salary        1
# Department    0
# dtype: int64

# %%
df[df["Salary"]>25000]
# Out:
#   Name   Age   Salary Department
# 2    C   NaN  30000.0         IT
# 4    E  30.0  50000.0         IT

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# HR    25000.000000
# IT    33333.333333
# Name: Salary, dtype: float64

# %%
df["Bonus"]= df["Salary"]*0.05

# %%
df["Bonus"]
# Out:
# 0    1000.0
# 1    1250.0
# 2    1500.0
# 3       NaN
# 4    2500.0
# Name: Bonus, dtype: float64

# %%
df
# Out:
#   Name   Age   Salary Department   Bonus
# 0    A  20.0  20000.0         IT  1000.0
# 1    B  22.0  25000.0         HR  1250.0
# 2    C   NaN  30000.0         IT  1500.0
# 3    D  25.0      NaN         HR     NaN
# 4    E  30.0  50000.0         IT  2500.0

# %%
df.fillna({
    "Age":df["Age"].mean(),
    "Salary" : df["Salary"].mean(),
    "Bonus" : df["Bonus"].mean()
        },inplace=True)

# %%
df
# Out:
#   Name    Age   Salary Department   Bonus
# 0    A  20.00  20000.0         IT  1000.0
# 1    B  22.00  25000.0         HR  1250.0
# 2    C  24.25  30000.0         IT  1500.0
# 3    D  25.00  31250.0         HR  1562.5
# 4    E  30.00  50000.0         IT  2500.0

# %%
df.to_csv("update.csv",index=False)

# %%
df
# Out:
#   Name    Age   Salary Department   Bonus
# 0    A  20.00  20000.0         IT  1000.0
# 1    B  22.00  25000.0         HR  1250.0
# 2    C  24.25  30000.0         IT  1500.0
# 3    D  25.00  31250.0         HR  1562.5
# 4    E  30.00  50000.0         IT  2500.0
